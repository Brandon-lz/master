# %%
import tensorflow as tf

# %%
# %pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 394.3 MB 32 kB/s s eta 0:00:01  |                                | 133 kB 8.2 MB/s eta 0:00:49     |▎                               | 3.9 MB 8.2 MB/s eta 0:00:48     |█████████                       | 110.7 MB 58.3 MB/s eta 0:00:05     |████████████▌                   | 153.4 MB 34.2 MB/s eta 0:00:08     |███████████████▏                | 186.4 MB 35.0 MB/s eta 0:00:06     |███████████████████▌            | 239.8 MB 25.5 MB/s eta 0:00:07
# ...
#      |████████████████████████████████| 462 kB 28.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 47.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.8 MB 31.2 MB/s eta 0:00:01     |███████████████████▍            | 2.3 MB 31.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 1.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 9.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 10.6 MB 30.8 MB/s eta 0:00:01
# ...

# %%
a = tf.random.normal([4,28,28,3])

# %%
a.shape,a.ndim
# Out:
# (TensorShape([4, 28, 28, 3]), 4)

# %% [markdown]
# ### reshape

# %%
tf.reshape(a,[4,784,3]).shape
# Out:
# TensorShape([4, 784, 3])

# %%
tf.reshape(a,[4,-1,3]).shape    #-1代表包含几个维度的所有通道数，但是只能使用一次-1
# Out:
# TensorShape([4, 784, 3])

# %%
tf.reshape(a,[4,784*3]).shape
# Out:
# TensorShape([4, 2352])

# %%
aa = tf.reshape(a,[4,-1])        #将数据维度打平
aa.shape
# Out:
# TensorShape([4, 2352])

# %%
#也可以用reshape将维度恢复
tf.reshape(aa,[4,28,28,3]).shape
# Out:
# TensorShape([4, 28, 28, 3])

# %% [markdown]
# ### tf.transpose   维度顺序变换

# %%
a = tf.random.normal([4,3,2,1])

# %%
a.shape
# Out:
# TensorShape([4, 3, 2, 1])

# %%
tf.transpose(a).shape
# Out:
# TensorShape([1, 2, 3, 4])

# %%
tf.transpose(a,perm=[0,1,3,2]).shape
# Out:
# TensorShape([4, 3, 1, 2])

# %% [markdown]
# <a href="https://colab.research.google.com/github/Brandon-lz/master/blob/main/aicodes/10%E6%B1%82%E6%A2%AF%E5%BA%A6/%E5%A4%9A%E5%B1%82%E5%A4%9A%E8%BE%93%E5%87%BA%E6%84%9F%E7%9F%A5%E6%9C%BA%E6%A2%AF%E5%BA%A6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %% [markdown]
# 多输出网络对某参数求导的公式：

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 多层、多输出网络对某参数的求导法则：

# %% [markdown]
# 这里研究两层的神经网络
#
# 每层的结果和参数命名规则如下图

# %% [markdown]
# ![BaiduShurufa_2021-2-19_14-4-37.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![BaiduShurufa_2021-2-19_14-4-37.png](data:image/png;base64,...)

# %% [markdown]
# 注：上式的б(xk)是sigmoid激活函数，然后第三行等式到第四行等式之间又经过了一个链式法则，加入了![image.png](data:image/png;base64,...)这一项

# %% [markdown]
# 第七行到第八行主要是转化偏O/偏w，这里还是老一套，将偏O先对xj求导，也就是激活函数求导，然后求输出对w参数求导，很容易得到是输入x0，但是图中写成了输入Oi的形式

# %% [markdown]
# ![BaiduShurufa_2021-2-19_14-4-37.png](data:image/png;base64,...)

# %% [markdown]
# 通过链式法则，一层一层的倒推前面层的梯度
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <a href="https://colab.research.google.com/github/Brandon-lz/master/blob/main/aicodes/10%E6%B1%82%E6%A2%AF%E5%BA%A6/%E5%A4%9A%E8%BE%93%E5%87%BA%E6%84%9F%E7%9F%A5%E6%9C%BA%E6%A2%AF%E5%BA%A6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %% [markdown]
# 对于多层感知机，每一层的节点、以及权值参数的上下标如下图所示

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 多层感知机的MSE对权值的梯度与单层感知机的梯度形式是相同的，对于求导对象来说，它的导数仅跟它所在的边的输入输出值有关，与其他边的值无关

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = tf.random.normal([2,4])
w = tf.random.normal([4,3])
b = tf.zeros([3])
y = tf.constant([2,0])
with tf.GradientTape() as tape:
  tape.watch([w,b])
  prob = tf.nn.softmax(x@w+b,axis=1)
  loss = tf.reduce_mean(tf.losses.MSE(tf.one_hot(y,depth=3),prob))
grads = tape.gradient(loss,[w,b])
grads[0]   #对w求梯度
# Out:
# <tf.Tensor: shape=(4, 3), dtype=float32, numpy=
# array([[-0.08134353,  0.0020174 ,  0.07932615],
#        [-0.04040438, -0.00073915,  0.04114353],
#        [-0.05897631, -0.00130464,  0.06028095],
#        [-0.01613008,  0.00110589,  0.01502419]], dtype=float32)>

# %%
grads[1]   #对b求梯度
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([-0.00992717,  0.00227663,  0.00765055], dtype=float32)>

# %%
tf.one_hot(y,depth=3)  #将结果onehot编码
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[0., 0., 1.],
#        [1., 0., 0.]], dtype=float32)>

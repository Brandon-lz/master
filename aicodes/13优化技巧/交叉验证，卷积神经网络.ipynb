# %% [markdown]
# <a href="https://colab.research.google.com/github/Brandon-lz/master/blob/main/aicodes/13%E4%BC%98%E5%8C%96%E6%8A%80%E5%B7%A7/%E4%BA%A4%E5%8F%89%E9%AA%8C%E8%AF%81%EF%BC%8C%E5%8D%B7%E7%A7%AF%E7%A5%9E%E7%BB%8F%E7%BD%91%E7%BB%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 每次训练都将数据打散，然后按比例分割出来，这样就是交叉验证了

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 还有一种方法是keras自带的，Model.fit()，将数据放进去，然后设置验证集占比为0.1，那么函数就会自动将数据按照9:1来分割训练集和测试集

# %% [markdown]
# ![image.png](data:image/png;base64,...)

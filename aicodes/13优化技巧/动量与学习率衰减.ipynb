# %% [markdown]
# <a href="https://colab.research.google.com/github/Brandon-lz/master/blob/main/aicodes/13%E4%BC%98%E5%8C%96%E6%8A%80%E5%B7%A7/%E5%8A%A8%E9%87%8F%E4%B8%8E%E5%AD%A6%E4%B9%A0%E7%8E%87%E8%A1%B0%E5%87%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Momentum 动量因子

# %% [markdown]
# 梯度更新的时候，没有动量因子的情况下是将原来的参数减去梯度。而有动量因子的情况下，则多减了一个β*上一个梯度，也就是将上一次的方向也加入到了这一次的梯度更新方向中来。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 接下来用一个直观的方法来解释动量因子对梯度更新的影响

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 在pytorch中可以通过设置momentum参数来增加动量因子，但是在tensorflow.keras中的optimizers优化器自带动量因子Adam，无需手动设置

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow.keras.optimizers as optimizer

# %%
optimizer.Adam()

# %% [markdown]
# Learning rate tunning 学习速率

# %% [markdown]
# #### 其实就是lr参数，作为梯度的系数，可以影响模型参数的变化幅度

# %% [markdown]
# ### Learning rate decay  学习速率衰减：动态地降低学习速率

# %% [markdown]
# tensorflow中调整learning_rate的方法，可以根据这个自己写更加复杂的优化算法

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 方法一：监听loss，如果loss很长时间都在一个小范围内徘徊，则将学习速率降低

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 方法二：设置经过一定的步数，每次降低一定的学习速率

# %% [markdown]
# ![image.png](data:image/png;base64,...)

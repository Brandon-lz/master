# %% [markdown]
# <a href="https://colab.research.google.com/github/Brandon-lz/master/blob/main/aicodes/14%E5%8D%B7%E7%A7%AF%E7%A5%9E%E7%BB%8F%E7%BD%91%E7%BB%9C/%E6%B1%A0%E5%8C%96%E4%B8%8E%E9%87%87%E6%A0%B7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   Pooling   （下采样subsample）
# *   upsample  （上采样）
# *   ReLU

# %% [markdown]
# ### Pooling

# %% [markdown]
# Pooling有两种主要的方法，一种是maxpolling，也就是取窗口中的最大值，另一种是avgpooling，取窗口值的平均值。
#
# Pooling也可以设置步长stride和padding
#
# Pooling不改变通道数

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## upsample

# %% [markdown]
# 这个用于放大图片

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ReLU

# %% [markdown]
# ![image.png](data:image/png;base64,...)
